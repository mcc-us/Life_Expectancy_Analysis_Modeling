# %% [markdown]
# # What Exactly Is Missing From Life Expectancy Dataset
#
# **Summary**
#
# - Investigating this dataset, I found the initial dataset had 193 unique country names.
#
# - I found 10 rows did not have Life Expectancy values.
#
# - Therefore, I wondered the missing values were located. Was it 1 country that was missing 10 rows (years) of or one year out of the 10 different sequences.
#
# - What seemed odd to me was that when I deleted the 10 rows with NAN of Life Expectancy I had 183 countries left.
#
# - By looking at the countries I found these 10 countries had only one entry each, for the year = 2013.

# %%
import numpy as np
import pandas as pd

# %%
path_filename = 'Life_Expectancy_Data.csv'

# Clean column names
column_names = ['Country','Year','Status','LifeExpectancy','AdultMort',
                'InfD','EtOH','PercExpen','HepB','Measles',
                'BMI','lt5yD','Polio','TotalExpen','DTP','HIV',
                'GDP','Population','Thin1_19y','Thin5_9y','Income',
                'Education']

df = pd.read_csv(path_filename, 
                 names=column_names, 
                 header=0)

# %%
df.loc[df['LifeExpectancy'].isnull()]
# Out:
#                     Country  Year      Status  LifeExpectancy  AdultMort  \
# 624            Cook Islands  2013  Developing             NaN        NaN
# 769                Dominica  2013  Developing             NaN        NaN
# 1650       Marshall Islands  2013  Developing             NaN        NaN
# 1715                 Monaco  2013  Developing             NaN        NaN
# 1812                  Nauru  2013  Developing             NaN        NaN
# 1909                   Niue  2013  Developing             NaN        NaN
# 1958                  Palau  2013  Developing             NaN        NaN
# 2167  Saint Kitts and Nevis  2013  Developing             NaN        NaN
# 2216             San Marino  2013  Developing             NaN        NaN
# 2713                 Tuvalu  2013  Developing             NaN        NaN
#
#       InfD  EtOH   PercExpen  HepB  Measles  ...  Polio  TotalExpen   DTP  \
# 624      0  0.01    0.000000  98.0        0  ...   98.0        3.58  98.0
# ...

# %%
df.loc[df['Country'] == 'Cook Islands']
# Out:
#           Country  Year      Status  LifeExpectancy  AdultMort  InfD  EtOH  \
# 624  Cook Islands  2013  Developing             NaN        NaN     0  0.01
#
#      PercExpen  HepB  Measles  ...  Polio  TotalExpen   DTP  HIV  GDP  \
# 624        0.0  98.0        0  ...   98.0        3.58  98.0  0.1  NaN
#
#      Population  Thin1_19y  Thin5_9y  Income  Education
# 624         NaN        0.1       0.1     NaN        NaN
#
# [1 rows x 22 columns]

# %%
df.loc[df['Country'] == 'Dominica']
# Out:
#       Country  Year      Status  LifeExpectancy  AdultMort  InfD  EtOH  \
# 769  Dominica  2013  Developing             NaN        NaN     0  0.01
#
#      PercExpen  HepB  Measles  ...  Polio  TotalExpen   DTP  HIV        GDP  \
# 769  11.419555  96.0        0  ...   96.0        5.58  96.0  0.1  722.75665
#
#      Population  Thin1_19y  Thin5_9y  Income  Education
# 769         NaN        2.7       2.6   0.721       12.7
#
# [1 rows x 22 columns]

# %%
df.loc[df['Country'] == 'Marshall Islands']
# Out:
#                Country  Year      Status  LifeExpectancy  AdultMort  InfD  \
# 1650  Marshall Islands  2013  Developing             NaN        NaN     0
#
#       EtOH   PercExpen  HepB  Measles  ...  Polio  TotalExpen   DTP  HIV  \
# 1650  0.01  871.878317   8.0        0  ...   79.0       17.24  79.0  0.1
#
#               GDP  Population  Thin1_19y  Thin5_9y  Income  Education
# 1650  3617.752354         NaN        0.1       0.1     NaN        0.0
#
# [1 rows x 22 columns]

# %%
df.loc[df['Country'] == 'Monaco']
# Out:
#      Country  Year      Status  LifeExpectancy  AdultMort  InfD  EtOH  \
# 1715  Monaco  2013  Developing             NaN        NaN     0  0.01
#
#       PercExpen  HepB  Measles  ...  Polio  TotalExpen   DTP  HIV  GDP  \
# 1715        0.0  99.0        0  ...   99.0         4.3  99.0  0.1  NaN
#
#       Population  Thin1_19y  Thin5_9y  Income  Education
# 1715         NaN        NaN       NaN     NaN        NaN
#
# [1 rows x 22 columns]

# %%
df.loc[df['Country'] == 'Nauru']
# Out:
#      Country  Year      Status  LifeExpectancy  AdultMort  InfD  EtOH  \
# 1812   Nauru  2013  Developing             NaN        NaN     0  0.01
#
#       PercExpen  HepB  Measles  ...  Polio  TotalExpen   DTP  HIV        GDP  \
# 1812  15.606596  87.0        0  ...   87.0        4.65  87.0  0.1  136.18321
#
#       Population  Thin1_19y  Thin5_9y  Income  Education
# 1812         NaN        0.1       0.1     NaN        9.6
#
# [1 rows x 22 columns]

# %%
df.loc[df['Country'] == 'Niue']
# Out:
#      Country  Year      Status  LifeExpectancy  AdultMort  InfD  EtOH  \
# 1909    Niue  2013  Developing             NaN        NaN     0  0.01
#
#       PercExpen  HepB  Measles  ...  Polio  TotalExpen   DTP  HIV  GDP  \
# 1909        0.0  99.0        0  ...   99.0         7.2  99.0  0.1  NaN
#
#       Population  Thin1_19y  Thin5_9y  Income  Education
# 1909         NaN        0.1       0.1     NaN        NaN
#
# [1 rows x 22 columns]

# %%
df.loc[df['Country'] == 'Palau']
# Out:
#      Country  Year      Status  LifeExpectancy  AdultMort  InfD  EtOH  \
# 1958   Palau  2013  Developing             NaN        NaN     0   NaN
#
#        PercExpen  HepB  Measles  ...  Polio  TotalExpen   DTP  HIV  \
# 1958  344.690631  99.0        0  ...   99.0        9.27  99.0  0.1
#
#              GDP  Population  Thin1_19y  Thin5_9y  Income  Education
# 1958  1932.12237       292.0        0.1       0.1   0.779       14.2
#
# [1 rows x 22 columns]

# %%
df.loc[df['Country'] == 'Saint Kitts and Nevis']
# Out:
#                     Country  Year      Status  LifeExpectancy  AdultMort  \
# 2167  Saint Kitts and Nevis  2013  Developing             NaN        NaN
#
#       InfD  EtOH  PercExpen  HepB  Measles  ...  Polio  TotalExpen   DTP  HIV  \
# 2167     0  8.54        0.0  97.0        0  ...   96.0        6.14  96.0  0.1
#
#       GDP  Population  Thin1_19y  Thin5_9y  Income  Education
# 2167  NaN         NaN        3.7       3.6   0.749       13.4
#
# [1 rows x 22 columns]

# %%
df.loc[df['Country'] == 'San Marino']
# Out:
#          Country  Year      Status  LifeExpectancy  AdultMort  InfD  EtOH  \
# 2216  San Marino  2013  Developing             NaN        NaN     0  0.01
#
#       PercExpen  HepB  Measles  ...  Polio  TotalExpen   DTP  HIV  GDP  \
# 2216        0.0  69.0        0  ...   69.0         6.5  69.0  0.1  NaN
#
#       Population  Thin1_19y  Thin5_9y  Income  Education
# 2216         NaN        NaN       NaN     NaN       15.1
#
# [1 rows x 22 columns]

# %%
df.loc[df['Country'] == 'Tuvalu']
# Out:
#      Country  Year      Status  LifeExpectancy  AdultMort  InfD  EtOH  \
# 2713  Tuvalu  2013  Developing             NaN        NaN     0  0.01
#
#       PercExpen  HepB  Measles  ...  Polio  TotalExpen  DTP  HIV         GDP  \
# 2713  78.281203   9.0        0  ...    9.0       16.61  9.0  0.1  3542.13589
#
#       Population  Thin1_19y  Thin5_9y  Income  Education
# 2713      1819.0        0.2       0.1     NaN        0.0
#
# [1 rows x 22 columns]

# %% [markdown]
# ### NOTE 1:
#
# - It appears that **ONLY 10 rows do not have Life Expectancy** values AND that these 10 rows are one of a kind. In other words **these countries have ONLY the year 2013 listed, NO OTHER**.
# - It is **reasonable to delete the ten countries which make up ten rows.**
# - It appears that **no other countries have missing values.**
